# %%
# Import libraries
import requests
import csv
import pandas as pd

# %%
# BSCScan API Setup
def call_api(user, originalHash, symbol, MIN, MAX):
    URL = "https://api.bscscan.com"
    API_KEY = "W9KUR7P8P2HU1R589IS48X4WVJV5B6Z8XC"
    START_BLOCK = "7906054"
    END_BLOCK = "7915038"
    USER_ADDRESS = user

    endpoint = "{}/api?module=account&action=tokentx&address={}&startblock={}&endblock={}&sort=asc&apikey={}".format(URL, USER_ADDRESS, START_BLOCK, END_BLOCK, API_KEY)
    response = requests.get(endpoint)
    JSON_DATA_RAW = response.json()
    
    # Check if user has any transactions in the time frame
    if(JSON_DATA_RAW["status"]=="1"):
        # Iterate over transactions
        for transaction in JSON_DATA_RAW["result"]:
            
            # Check for token symbol
            if(transaction["tokenSymbol"] == symbol):
                value = int(transaction['value']) / pow(10, int(transaction["tokenDecimal"]))
                
                # Check if value is same
                if(int(value) in range(MIN, MAX)):
#                     print("Same token, same value, {}, Original Hash: {}".format(transaction['hash'], originalHash))
                    return transaction['hash']

                # Values not same
                else:
#                     print("Same token, different value, {}, Original Hash: {}".format(transaction['hash'], originalHash))
                    return 0
            
            # Different token
            else:
#                 print("Different token, {}".format(transaction['hash']))
                return 0
    
    # No transactions by the user in the time frame
    else:
#         print("No transaction")
        return 0

# %%
df = pd.read_csv('posbridge.csv')
df["value"] = df["value"].astype(float)
df['ValueDecimal'] = df['value'] / pow(10, df["tokenDecimal"])
df.head()
# Out:
#    blockNumber   timeStamp                                               hash  \
# 0     12540857  1622447001  0xdc90167a370a245aa92cfa9b3555607bed72dc12134e...
# 1     12540872  1622447259  0x28b7b78f3a37dce35b22eb2da3cb05d31ffea27d5d7e...
# 2     12540878  1622447360  0xd0fe670573dcd6d3019f61a133d12a5249ad48f658e6...
# 3     12540880  1622447397  0xb2f12422d96df2b2f27c878abebedbe8ce5efdc46afd...
# 4     12540880  1622447397  0x082bd1719662720fe1e2ef4bdb7d41caad152d025257...
#
#    nonce                                          blockHash  \
# 0    234  0x81dc24a962b0e2eac7d2a20cd4478a70394e221f0c0b...
# 1    122  0x6cd5f0b9e71b95cb527995b3e43d92110c623046b7af...
# 2    111  0x45052146bf0d3777ddef37579b0b30884caf31ec8abb...
# 3    962  0x0288cba799a16b65c4fed565f0165f3022f6101b205e...
# 4     77  0x0288cba799a16b65c4fed565f0165f3022f6101b205e...
#
#                                          from  \
# 0  0x9de5fb2e82681cbf0f9885b2e17c7aadaf7c6a32
# 1  0x40ec5b33f54e0e8a33a975908c5ba1c14e5bbbdf
# 2  0x40ec5b33f54e0e8a33a975908c5ba1c14e5bbbdf
# 3  0x40ec5b33f54e0e8a33a975908c5ba1c14e5bbbdf
# 4  0xe73c4e077a9fcd02b590f8c275773401e5f95dbd
#
#                               contractAddress  \
# 0  0xe53ec727dbdeb9e2d5456c3be40cff031ab40a55
# 1  0xa283aa7cfbb27ef0cfbcb2493dd9f4330e0fd304
# 2  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#                                            to         value   tokenName  \
# 0  0x40ec5b33f54e0e8a33a975908c5ba1c14e5bbbdf  2.500000e+20   SuperFarm
# 1  0xe80a9bd7bc44f1fcd0af160459528f4ecdd38698  6.000000e+20     MMToken
# 2  0x92eced51de33d79dc6ab1f10acb5576bddbaa665  3.000223e+09  Tether USD
# 3  0x7bcd790d1282622da859625f3786be9f33042d50  1.996188e+09    USD Coin
# 4  0x40ec5b33f54e0e8a33a975908c5ba1c14e5bbbdf  1.199730e+11    USD Coin
#
#   tokenSymbol  tokenDecimal  transactionIndex     gas     gasPrice  gasUsed  \
# 0       SUPER            18                93  102329  27000000000    79860
# 1          MM            18               112  259710  20000000000   244390
# 2        USDT             6               109  307701  23000000000   292042
# 3        USDC             6               398  280967  26000000000   264260
# 4        USDC             6               425  114687  25000000000    92218
#
#    cumulativeGasUsed       input  confirmations   ValueDecimal
# 0            5009262  deprecated          47476     250.000000
# 1            9537950  deprecated          47461     600.000000
# 2            7703123  deprecated          47455    3000.222812
# 3           11388695  deprecated          47453    1996.188028
# 4           12929653  deprecated          47453  119973.000000

# %%
columnList = list(df.columns)
columnList.append("BSC Hash")
columnList.append("Type")
filteredDf = pd.DataFrame(columns = columnList)

for index, row in df.head(200).iterrows():
    USER_ADDRESS = ""
    TYPE = ""
    FLAG = False
    if(row["from"]=="0x40ec5b33f54e0e8a33a975908c5ba1c14e5bbbdf"):
        USER_ADDRESS = row["to"]
        TYPE = "OUT" # Out of Polygon
    else:
        USER_ADDRESS = row["from"]
        TYPE = "IN" # Into Polygon
    
    MIN = row["ValueDecimal"] - 100
    MAX = row["ValueDecimal"] + 100
    
    if(call_api(USER_ADDRESS, row['hash'], row['tokenSymbol'], int(MIN), int(MAX))!=0):
        print(index)
        filteredDf.loc[index] = df.iloc[index]
        filteredDf.loc[index, 'BSC Hash'] = call_api(USER_ADDRESS, row['hash'], row['tokenSymbol'], int(MIN), int(MAX))
        if(TYPE == "IN"):
            filteredDf.loc[index, 'Destination'] = "Polygon"
        elif(TYPE == "OUT"):
            filteredDf.loc[index, 'Destination'] = "BSC"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c6c44bf9ac37> in <module>
#      18     MAX = row["ValueDecimal"] + 100
#      19
# ---> 20     if(call_api(USER_ADDRESS, row['hash'], row['tokenSymbol'], int(MIN), int(MAX))!=0):
#      21         print(index)
#      22         filteredDf.loc[index] = df.iloc[index]
#
# NameError: name 'call_api' is not defined

# %%
filteredDf
# Out:
#     blockNumber   timeStamp  \
# 92     12546298  1622519698
# 97     12546301  1622519743
# 173    12546394  1622520937
#
#                                                   hash nonce  \
# 92   0xc80c7e4667a9703599fa20262d09784f6c9eb97f02f6...    15
# 97   0x70d3abf8915080f00964e6293319283f622f5da8f199...    16
# 173  0x4826eca2a9e918590b397eb239773a1ab36593c3d1f7...     1
#
#                                              blockHash  \
# 92   0x8e7f7012061273c0fdf3968ca87863e9d62742d2f7b8...
# 97   0x779d253270c04d728dafb26209810156a9af36da3394...
# 173  0xf1990605b7dc33681d19cbd8ff61e457e2848da4a8d9...
#
#                                            from  \
# 92   0x46aaa27dbc0c4d4d1c8afb81e7e032d44e0fde36
# 97   0x95c2ec97903c993efbe4630f1535282a12fead98
# 173  0x74f40d36f515ae1849e46d900648565b0bda0841
#
#                                 contractAddress  \
# 92   0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 97   0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 173  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#                                              to         value tokenName  ...  \
# 92   0x40ec5b33f54e0e8a33a975908c5ba1c14e5bbbdf  1.210558e+10  USD Coin  ...
# 97   0x40ec5b33f54e0e8a33a975908c5ba1c14e5bbbdf  4.655000e+09  USD Coin  ...
# 173  0x40ec5b33f54e0e8a33a975908c5ba1c14e5bbbdf  3.969048e+09  USD Coin  ...
#
#         gas     gasPrice gasUsed cumulativeGasUsed       input confirmations  \
# 92   114687  25000000000   92218           6575803  deprecated          1973
# 97   114687  20000000000   92218          11747207  deprecated          1970
# 173  114675  17000000000   92206           2873709  deprecated          1877
#
#      ValueDecimal                                           BSC Hash Type  \
# 92   12105.584884  0x04cc20070cf9aea1070b2c074330097674476ce028d6...  NaN
# 97    4655.000000  0x9926c941d4d713e88fb995f0bf600c88863fc51b4018...  NaN
# 173   3969.047721  0xcea76fbf6d5c50f067e092085f41e7ebb2fbb9d8b1d2...  NaN
#
#      Destination
# 92       Polygon
# 97       Polygon
# 173      Polygon
#
# [3 rows x 23 columns]

# %%
filteredDf.to_csv('filteredDf.csv')
